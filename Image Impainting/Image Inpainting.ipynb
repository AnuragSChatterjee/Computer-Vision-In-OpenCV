# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

img = cv.imread(r"C:\Users\Anura\Desktop\anurag photo.jpg") #Read my photo

mask = cv.imread(r"C:\Users\Anura\Desktop\anurag photo.jpg", cv.IMREAD_GRAYSCALE)

dst = cv.inpaint(img,mask,3,cv.INPAINT_TELEA)
plt.imshow(dst)
